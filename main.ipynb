# %%
import gradio as gr
from downloader import download_video  # Replace with your actual module and function

def video_downloader(video_link, download_path="downloads/"):
    # Call your video downloader function here with video_link and download_path
    download_video(video_link, download_path)
    return "Video downloaded successfully to downloads".format(download_path)

iface = gr.Interface(
    fn=video_downloader,
    inputs=["text"],
    outputs="text",
    live=False,
    title="📺YouTube-Downloaderr📺",
    description="Paste youtube url🎥",
    # capture_session=True
    theme='HaleyCH/HaleyCH_Theme',
    allow_flagging="never",
)
iface.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7866
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7866/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Exception in thread Thread-33 (_do_normal_analytics_request):
# Traceback (most recent call last):
#   File "c:\Users\Tejas\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpcore\_exceptions.py", line 10, in map_exceptions
#     yield
#   File "c:\Users\Tejas\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpcore\_backends\sync.py", line 168, in start_tls
#     raise exc
#   File "c:\Users\Tejas\AppData\Local\Programs\Python\Python311\Lib\site-packages\httpcore\_backends\sync.py", line 163, in start_tls
#     sock = ssl_context.wrap_socket(
#            ^^^^^^^^^^^^^^^^^^^^^^^^
# ...
